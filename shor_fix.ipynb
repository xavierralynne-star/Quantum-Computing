# %% [markdown]
# ### Import Library ###

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from fractions import Fraction
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator

# %% [markdown]
# ### Inisialisasi ###

# %%
N1, a1 = 15, 2
shots = 20000                           #Jumlah pengukuran (runs) per simulasi
n_count1 = math.ceil(math.log2(N1**2))  #8 kubit
Q1 = 2**n_count1                        #256

# %%
N2, a2 = 111, 2
n_count2 = math.ceil(math.log2(N2**2))      # 14 kubit
Q2 = 2**n_count2

# %%
def c_amod15(a, power):
    # Normalisasi a agar nilainya dalam range 0-14
    a = a % 15
    # Validasi: a harus relatif prima dengan 15
    # syarat Shor's algorithm: gcd(a,N)=1
    # jika tidak, faktor sudah ditemukan secara klasik
    if math.gcd(a, 15) != 1:
        raise ValueError(f"gcd({a},15) != 1")

    U = QuantumCircuit(4)           # Buat quantum circuit dengan 4 qubit (work register)
    # Ulangi operasi sebanyak 'power' kali
    # misal power=4 → U diterapkan 4 kali = U^4
    for _ in range(power):
        if a == 2:                  # 2*y mod 15: geser bit ke kiri (rotasi siklik)                 
            U.swap(0, 1); U.swap(1, 2); U.swap(2, 3)
        elif a == 4:                # 4*y mod 15: geser 2 bit ke kiri
            U.swap(0, 2); U.swap(1, 3)
        elif a == 7:                # 7*y mod 15: kebalikan dari a=2
            U.swap(2, 3); U.swap(1, 2); U.swap(0, 1)
        elif a == 8:                # 8*y mod 15: kombinasi rotasi
            U.swap(2, 3); U.swap(0, 2); U.swap(1, 3)
        elif a == 11:               # 11*y mod 15: 11 = -4 mod 15, kebalikan dari a=4
            U.swap(1, 3); U.swap(0, 2)
        elif a == 13:               # 13*y mod 15: 13 = -2 mod 15, kebalikan dari a=2
            U.swap(0, 3); U.swap(1, 2)
        else:
            raise ValueError(f"a={a} belum didukung untuk N=15")    # a selain di atas tidak didukung untuk N=15

    c_U = U.to_gate().control(1)    # Konversi circuit U menjadi gate
                                    # lalu tambahkan 1 control qubit → controlled-U gate
    c_U.label = f"a^{power} mod 15" # Beri label untuk memudahkan visualisasi circuit
    return c_U

# %%
def c_amod_N(a, power, N, n_work):
    # Hitung dimensi Hilbert space = 2^n_work
    dim = 2**n_work

    # Hitung a^power mod N secara klasik
    # pow(a, power, N) = fast modular exponentiation
    a_pow = pow(int(a), int(power), int(N))
    # Matriks permutasi
    # matriks ini merepresentasikan U|y⟩ = |a^power * y mod N⟩
    U = np.zeros((dim,dim))
    for y in range(dim):
        # Jika y < N: terapkan perkalian modular
        # Jika y >= N: biarkan state tidak berubah (identitas)    
        new_y = (a_pow*y) % N if y < N else y 
        U[new_y,y] = 1.0        # artinya: state |y⟩ dipetakan ke state |new_y⟩

# Buat quantum circuit dengan n_work qubit
    gate = QuantumCircuit(n_work, name=f'U^{power} mod {N}')
    # Masukkan matriks U sebagai unitary gate
    gate.unitary(U, list(range(n_work)))
    # controlled-U: jika control=|1⟩ → terapkan U
    #               jika control=|0⟩ → tidak terjadi apa-apa
    return gate.to_gate().control(1)

# %%
# Exact QFT
# Inverse QFT (QFT†) - digunakan di akhir QPE
# QFT† = kebalikan dari QFT, untuk mengekstrak informasi fase
def qft_dagger(circuit, n):
    # Stage 1: Balik urutan qubit (bit-reversal)
    # karena output QFT urutan bit-nya terbalik
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)
        # n=8: swap(0,7), swap(1,6), swap(2,5), swap(3,4)

    # Stage 2: Controlled-phase negatif + Hadamard
    # negatif karena ini INVERSE QFT (kebalikan QFT biasa)
    for j in range(n):
        for m in range(j):
            # sudut makin kecil saat j-m makin besar
            circuit.cp(-np.pi/(2**(j-m)), m, j)
        # Hadamard setelah semua rotasi fase selesai
        circuit.h(j)

# %%
# Approximate QFT
# Memangkas gate dengan sudut rotasi sangat kecil (< π/2^kmax)
# Mengurangi jumlah gate dari O(L²) → O(L log L)
def approx_qft_dagger(circuit, n, kmax):    # kmax = threshold maksimum jarak qubit yang masih dirotasi

    # Stage 1: Balik urutan qubit (sama seperti exact QFT†)
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)

    # Stage 2: Controlled-phase negatif + Hadamard
    # dengan threshold kmax
    for j in range(n):
        for m in range(j):
            if (j-m) <= kmax:               # Gate DIPAKAI jika jarak j-m masih dalam threshold
                circuit.cp(-np.pi/(2**(j-m)), m, j)
                # Gate DIPANGKAS jika (j-m) > kmax

        circuit.h(j)

# %%
#Build full Shor's circuit (QPE + Modular exp)
def build_circuit(N, a, n_count, use_approx=False):

    n_work = 4 if N==15 else math.ceil(math.log2(N+1))
    qc = QuantumCircuit(n_count + n_work, n_count)

    #Hadamard pada counting register
    for q in range(n_count): 
        qc.h(q)     #n_count qubit dikenai Hadamard, untuk estimasi fase

    #inisialisasi work register ke |1> 
    qc.x(n_count) #n_work qubit (lower/work register), tempat modular exponentiaton

    #Controlled-U^(2^k)
    for k in range(n_count):
        power = 2**k
        if N == 15:
            cu = c_amod15(a, power)
        else:
            cu = c_amod_N(a, power, N, n_work)
        #control = kubit k, target = work register
        qc.append(cu, [k] + list(range(n_count, n_count + n_work)))

    #Inverse QFT pada counting register
    if use_approx:
        kmax = max (1, int(np.log2(n_count))-2)
        approx_qft_dagger(qc, n_count, kmax)
    else:
        qft_dagger(qc, n_count)

    #Ukur counting register
    for i in range(n_count):
        qc.measure(i,i)

    return qc

# %%
#Simulasi (probability array)
def simulate(qc, Q):
    sim = AerSimulator()
    tqc = transpile(qc, sim)
    result = sim.run(tqc, shots=shots).result()
    counts = result.get_counts()

    prob = np.zeros(Q)
    for state,count in counts.items():
        prob[int(state,2)] = count/shots

    return prob

# %%
#Menghitung periode r
def get_period_classical(a,N):
    r = 1   #mulai hitung dari eksponen 1
    val = a % N #val = a^1 mod N

    while val != 1 and r < N * 10:  #terus kalikan sampai val = 1
        val = (val*a) % N   #val = a^(r+1) mod N
        r = r+1
    return r    #r = period yg ditemukan

# %%
#Distribusi teoritis
def theory_distribution(r, Q):
    prob = np.zeros(Q)
    for x in range(Q):
        total = 0
        for s in range(r):
            peak = s * Q / r
            diff = x - peak
            if abs(diff) < 1e-10:
                total += 1.0 / r
            else:
                num = np.sin(np.pi * diff)
                den = Q * np.sin(np.pi * diff / Q)
                if abs(den) > 1e-10:
                    total += (1/r) * (num/den) ** 2
        prob[x] = total

    # Normalisasi
    if prob.sum() > 0:
        prob = prob / prob.sum()

    # Buang nilai yang terlalu kecil (noise)
    threshold = 0.5 / r   # setengah dari nilai peak
    prob[prob < threshold] = 0
    
    # Normalisasi ulang setelah threshold
    if prob.sum() > 0:
        prob = prob / prob.sum()
    
    return prob

# %%
#Menghitung brp persen shots yg berhasil menemukan faktor N.
def correctness(counts, n_count, N, a, shots, label=''):
    r = get_period_classical(a,N)
    Q = 2**n_count  #jumlah total states(256 utk N=15)
    good = 0        #counter shots yg berhasil
    for state, count in counts.items():
        x = int(state, 2)   #konversi bitstring '01000000' angka 64
        if x == 0:
            continue        #skip state 0 
        phase = x / Q       #misal x=64, Q=256 → phase = 64/256 = 0.25
                            #ini estimasi dari s/r (s adalah integer 0..r-1)
        frac = Fraction(phase).limit_denominator(N)
        r_candidate = frac.denominator  #Continued fraction algorithm:
                                        # 0.25 → Fraction(1/4) → denominator = 4
        if r_candidate % 2 == 0:       #r harus genap
            guess1 = math.gcd(pow(int(a), r_candidate // 2, int(N)) + 1, N)
            guess2 = math.gcd(pow(int(a), r_candidate // 2, int(N)) - 1, N)
            if 1 < guess1 < N or 1 < guess2 < N:
                good += count
                print(f'[{label}] state={x}, phase={phase:.4f}, r={r_candidate}, faktor={guess1} dan {guess2}')
    return good / shots * 100       #persentase

# %%
#Jalankan simulasi
#N = 15
shots_15 = 20000
print('N=15 Exact QFT...')
qc_exact1 = build_circuit(N1, a1, n_count1, use_approx=False)
print('N=15 Approx QFT...')
qc_approx1 = build_circuit(N1, a1, n_count1 ,use_approx=True)

sim = AerSimulator()
res_exact1 = sim.run(transpile(qc_exact1, sim), shots=shots_15).result()
res_approx1 = sim.run(transpile(qc_approx1, sim), shots=shots_15).result()

prob_exact1 = simulate(qc_exact1, Q1)
prob_approx1 = simulate(qc_approx1, Q1)
prob_theory1 = theory_distribution(get_period_classical(a1, N1), Q1)

CE1 = correctness(res_exact1.get_counts(), n_count1, N1, a1, shots_15, label='N=15 Exact')
CA1 = correctness(res_approx1.get_counts(), n_count1, N1, a1, shots_15, label='N=15 Approx')

#N = 111
shots_111 = 1024
print('N=111 Exact QFT...')
qc_exact2 = build_circuit(N2, a2, n_count2, use_approx=False)
print('N=111 Approx QFT...')
qc_approx2 = build_circuit(N2, a2, n_count2 ,use_approx=True)

res_exact2 = sim.run(transpile(qc_exact2, sim), shots=shots_111).result()
res_approx2 = sim.run(transpile(qc_approx2, sim), shots=shots_111).result()

prob_exact2 = simulate(qc_exact2, Q2)
prob_approx2 = simulate(qc_approx2, Q2)
prob_theory2 = theory_distribution(get_period_classical(a2, N2), Q2)

CE2 = correctness(res_exact2.get_counts(), n_count2, N2, a2, shots_111, label ='N=111 Exact')
CA2 = correctness(res_approx2.get_counts(), n_count2, N2, a2, shots_111, label ='N=111 Approx')

print(f"\nCorrectness N=15  → Exact: {CE1:.2f}%  Approx: {CA1:.2f}%")
print(f"Correctness N=111 → Exact: {CE2:.2f}%  Approx: {CA2:.2f}%")
# Out:
# N=15 Exact QFT...
# N=15 Approx QFT...
# [N=15 Exact] state=128, phase=0.5000, r=2, faktor=3 dan 1
# [N=15 Exact] state=192, phase=0.7500, r=4, faktor=5 dan 3
# [N=15 Exact] state=64, phase=0.2500, r=4, faktor=5 dan 3
# [N=15 Approx] state=192, phase=0.7500, r=4, faktor=5 dan 3
# [N=15 Approx] state=128, phase=0.5000, r=2, faktor=3 dan 1
# [N=15 Approx] state=64, phase=0.2500, r=4, faktor=5 dan 3
# N=111 Exact QFT...
# N=111 Approx QFT...
# [N=111 Exact] state=10011, phase=0.6110, r=18, faktor=3 dan 1
# [N=111 Exact] state=6832, phase=0.4170, r=12, faktor=1 dan 3
# [N=111 Exact] state=15018, phase=0.9166, r=12, faktor=1 dan 3
# [N=111 Exact] state=13199, phase=0.8056, r=36, faktor=37 dan 3
# [N=111 Exact] state=2731, phase=0.1667, r=6, faktor=3 dan 1
# [N=111 Exact] state=15019, phase=0.9167, r=12, faktor=1 dan 3
# [N=111 Exact] state=9558, phase=0.5834, r=12, faktor=1 dan 3
# [N=111 Exact] state=6823, phase=0.4164, r=12, faktor=1 dan 3
# [N=111 Exact] state=5917, phase=0.3611, r=36, faktor=37 dan 3
# [N=111 Exact] state=1366, phase=0.0834, r=12, faktor=1 dan 3
# [N=111 Exact] state=909, phase=0.0555, r=18, faktor=3 dan 1
# [N=111 Exact] state=10009, phase=0.6109, r=18, faktor=3 dan 1
# [N=111 Exact] state=4551, phase=0.2778, r=18, faktor=3 dan 1
# [N=111 Exact] state=12288, phase=0.7500, r=4, faktor=1 dan 3
# [N=111 Exact] state=5007, phase=0.3056, r=36, faktor=37 dan 3
# [N=111 Exact] state=5916, phase=0.3611, r=36, faktor=37 dan 3
# [N=111 Exact] state=6827, phase=0.4167, r=12, faktor=1 dan 3
# [N=111 Exact] state=10467, phase=0.6389, r=36, faktor=37 dan 3
# [N=111 Exact] state=9555, phase=0.5832, r=12, faktor=1 dan 3
# [N=111 Exact] state=11378, phase=0.6945, r=36, faktor=37 dan 3
# [N=111 Exact] state=15021, phase=0.9168, r=12, faktor=1 dan 3
# [N=111 Exact] state=15929, phase=0.9722, r=36, faktor=37 dan 3
# [N=111 Exact] state=15473, phase=0.9444, r=18, faktor=3 dan 1
# [N=111 Exact] state=8192, phase=0.5000, r=2, faktor=3 dan 1
# [N=111 Exact] state=5006, phase=0.3055, r=36, faktor=37 dan 3
# [N=111 Exact] state=14109, phase=0.8611, r=36, faktor=37 dan 3
# [N=111 Exact] state=455, phase=0.0278, r=36, faktor=37 dan 3
# [N=111 Exact] state=13198, phase=0.8055, r=36, faktor=37 dan 3
# [N=111 Exact] state=2277, phase=0.1390, r=36, faktor=37 dan 3
# [N=111 Exact] state=3185, phase=0.1944, r=36, faktor=37 dan 3
# [N=111 Exact] state=910, phase=0.0555, r=18, faktor=3 dan 1
# [N=111 Exact] state=14107, phase=0.8610, r=36, faktor=37 dan 3
# [N=111 Exact] state=3177, phase=0.1939, r=98, faktor=3 dan 1
# [N=111 Exact] state=15475, phase=0.9445, r=18, faktor=3 dan 1
# [N=111 Exact] state=14108, phase=0.8611, r=36, faktor=37 dan 3
# [N=111 Exact] state=6831, phase=0.4169, r=12, faktor=1 dan 3
# [N=111 Exact] state=7737, phase=0.4722, r=36, faktor=37 dan 3
# [N=111 Exact] state=15474, phase=0.9445, r=18, faktor=3 dan 1
# [N=111 Exact] state=3186, phase=0.1945, r=36, faktor=37 dan 3
# [N=111 Exact] state=10469, phase=0.6390, r=36, faktor=37 dan 3
# [N=111 Exact] state=4096, phase=0.2500, r=4, faktor=1 dan 3
# [N=111 Exact] state=10016, phase=0.6113, r=18, faktor=3 dan 1
# [N=111 Exact] state=6373, phase=0.3890, r=18, faktor=3 dan 1
# [N=111 Exact] state=1364, phase=0.0833, r=12, faktor=1 dan 3
# [N=111 Exact] state=6371, phase=0.3889, r=18, faktor=3 dan 1
# [N=111 Exact] state=13653, phase=0.8333, r=6, faktor=3 dan 1
# [N=111 Exact] state=2275, phase=0.1389, r=36, faktor=37 dan 3
# [N=111 Exact] state=6826, phase=0.4166, r=12, faktor=1 dan 3
# [N=111 Exact] state=7292, phase=0.4451, r=110, faktor=3 dan 1
# [N=111 Exact] state=1369, phase=0.0836, r=12, faktor=1 dan 3
# [N=111 Exact] state=10013, phase=0.6111, r=18, faktor=3 dan 1
# [N=111 Exact] state=11832, phase=0.7222, r=18, faktor=3 dan 1
# [N=111 Exact] state=2730, phase=0.1666, r=6, faktor=3 dan 1
# [N=111 Exact] state=14110, phase=0.8612, r=36, faktor=37 dan 3
# [N=111 Exact] state=454, phase=0.0277, r=36, faktor=37 dan 3
# [N=111 Exact] state=10012, phase=0.6111, r=18, faktor=3 dan 1
# [N=111 Exact] state=5939, phase=0.3625, r=80, faktor=1 dan 3
# [N=111 Exact] state=5005, phase=0.3055, r=36, faktor=37 dan 3
# [N=111 Exact] state=11833, phase=0.7222, r=18, faktor=3 dan 1
# [N=111 Exact] state=3188, phase=0.1946, r=36, faktor=37 dan 3
# [N=111 Exact] state=6372, phase=0.3889, r=18, faktor=3 dan 1
# [N=111 Exact] state=13655, phase=0.8334, r=6, faktor=3 dan 1
# [N=111 Exact] state=5918, phase=0.3612, r=36, faktor=37 dan 3
# [N=111 Exact] state=15020, phase=0.9167, r=12, faktor=1 dan 3
# [N=111 Exact] state=10014, phase=0.6112, r=18, faktor=3 dan 1
# [N=111 Exact] state=13654, phase=0.8334, r=6, faktor=3 dan 1
# [N=111 Exact] state=9557, phase=0.5833, r=12, faktor=1 dan 3
# [N=111 Exact] state=10015, phase=0.6113, r=18, faktor=3 dan 1
# [N=111 Exact] state=5493, phase=0.3353, r=110, faktor=3 dan 1
# [N=111 Exact] state=10468, phase=0.6389, r=36, faktor=37 dan 3
# [N=111 Exact] state=6825, phase=0.4166, r=12, faktor=1 dan 3
# [N=111 Exact] state=7736, phase=0.4722, r=36, faktor=37 dan 3
# [N=111 Exact] state=5915, phase=0.3610, r=36, faktor=37 dan 3
# [N=111 Exact] state=8647, phase=0.5278, r=36, faktor=37 dan 3
# [N=111 Exact] state=911, phase=0.0556, r=18, faktor=3 dan 1
# [N=111 Exact] state=9559, phase=0.5834, r=12, faktor=1 dan 3
# [N=111 Exact] state=2276, phase=0.1389, r=36, faktor=37 dan 3
# [N=111 Exact] state=10010, phase=0.6110, r=18, faktor=3 dan 1
# [N=111 Exact] state=1365, phase=0.0833, r=12, faktor=1 dan 3
# [N=111 Exact] state=15016, phase=0.9165, r=12, faktor=1 dan 3
# [N=111 Exact] state=4549, phase=0.2776, r=18, faktor=3 dan 1
# [N=111 Approx] state=13397, phase=0.8177, r=104, faktor=1 dan 3
# [N=111 Approx] state=2987, phase=0.1823, r=104, faktor=1 dan 3
# [N=111 Approx] state=11947, phase=0.7292, r=48, faktor=1 dan 3
# [N=111 Approx] state=15546, phase=0.9489, r=98, faktor=3 dan 1
# [N=111 Approx] state=3308, phase=0.2019, r=104, faktor=1 dan 3
# [N=111 Approx] state=11642, phase=0.7106, r=38, faktor=3 dan 1
# [N=111 Approx] state=975, phase=0.0595, r=84, faktor=1 dan 3
# [N=111 Approx] state=15092, phase=0.9211, r=38, faktor=3 dan 1
# [N=111 Approx] state=6329, phase=0.3863, r=44, faktor=1 dan 3
# [N=111 Approx] state=13909, phase=0.8489, r=86, faktor=3 dan 1
# [N=111 Approx] state=235, phase=0.0143, r=70, faktor=3 dan 1
# [N=111 Approx] state=14492, phase=0.8845, r=26, faktor=3 dan 1
# [N=111 Approx] state=11103, phase=0.6777, r=90, faktor=3 dan 1
# [N=111 Approx] state=5006, phase=0.3055, r=36, faktor=37 dan 3
# [N=111 Approx] state=13925, phase=0.8499, r=20, faktor=1 dan 3
# [N=111 Approx] state=15538, phase=0.9484, r=58, faktor=3 dan 1
# [N=111 Approx] state=4779, phase=0.2917, r=24, faktor=1 dan 3
# [N=111 Approx] state=15537, phase=0.9483, r=58, faktor=3 dan 1
# [N=111 Approx] state=14678, phase=0.8959, r=48, faktor=1 dan 3
# [N=111 Approx] state=12970, phase=0.7916, r=24, faktor=1 dan 3
# [N=111 Approx] state=7338, phase=0.4479, r=96, faktor=1 dan 3
# [N=111 Approx] state=2923, phase=0.1784, r=28, faktor=1 dan 3
# [N=111 Approx] state=11434, phase=0.6979, r=96, faktor=1 dan 3
# [N=111 Approx] state=1509, phase=0.0921, r=76, faktor=1 dan 3
# [N=111 Approx] state=7997, phase=0.4881, r=84, faktor=1 dan 3
# [N=111 Approx] state=5753, phase=0.3511, r=94, faktor=3 dan 1
# [N=111 Approx] state=12092, phase=0.7380, r=42, faktor=3 dan 1
# [N=111 Approx] state=11043, phase=0.6740, r=46, faktor=3 dan 1
# [N=111 Approx] state=15937, phase=0.9727, r=110, faktor=3 dan 1
# [N=111 Approx] state=4552, phase=0.2778, r=18, faktor=3 dan 1
# [N=111 Approx] state=1366, phase=0.0834, r=12, faktor=1 dan 3
# [N=111 Approx] state=4915, phase=0.3000, r=10, faktor=3 dan 1
# [N=111 Approx] state=2275, phase=0.1389, r=36, faktor=37 dan 3
# [N=111 Approx] state=2277, phase=0.1390, r=36, faktor=37 dan 3
# [N=111 Approx] state=454, phase=0.0277, r=36, faktor=37 dan 3
# [N=111 Approx] state=10726, phase=0.6547, r=84, faktor=1 dan 3
# [N=111 Approx] state=3705, phase=0.2261, r=84, faktor=1 dan 3
# [N=111 Approx] state=3115, phase=0.1901, r=100, faktor=1 dan 3
# [N=111 Approx] state=6863, phase=0.4189, r=74, faktor=3 dan 1
# [N=111 Approx] state=471, phase=0.0287, r=104, faktor=1 dan 3
# [N=111 Approx] state=15018, phase=0.9166, r=12, faktor=1 dan 3
# [N=111 Approx] state=6046, phase=0.3690, r=84, faktor=1 dan 3
# [N=111 Approx] state=10045, phase=0.6131, r=106, faktor=3 dan 1
# [N=111 Approx] state=7410, phase=0.4523, r=42, faktor=3 dan 1
# [N=111 Approx] state=15342, phase=0.9364, r=110, faktor=3 dan 1
# [N=111 Approx] state=14506, phase=0.8854, r=96, faktor=1 dan 3
# [N=111 Approx] state=9553, phase=0.5831, r=12, faktor=1 dan 3
# [N=111 Approx] state=10994, phase=0.6710, r=76, faktor=1 dan 3
# [N=111 Approx] state=12124, phase=0.7400, r=50, faktor=3 dan 1
# [N=111 Approx] state=5022, phase=0.3065, r=62, faktor=3 dan 1
# [N=111 Approx] state=6372, phase=0.3889, r=18, faktor=3 dan 1
# [N=111 Approx] state=4555, phase=0.2780, r=18, faktor=3 dan 1
# [N=111 Approx] state=1369, phase=0.0836, r=12, faktor=1 dan 3
# [N=111 Approx] state=12759, phase=0.7787, r=104, faktor=1 dan 3
# [N=111 Approx] state=2828, phase=0.1726, r=110, faktor=3 dan 1
# [N=111 Approx] state=13657, phase=0.8336, r=6, faktor=3 dan 1
# [N=111 Approx] state=2731, phase=0.1667, r=6, faktor=3 dan 1
# [N=111 Approx] state=12146, phase=0.7413, r=58, faktor=3 dan 1
# [N=111 Approx] state=13713, phase=0.8370, r=92, faktor=1 dan 3
# [N=111 Approx] state=14677, phase=0.8958, r=48, faktor=1 dan 3
# [N=111 Approx] state=6486, phase=0.3959, r=48, faktor=1 dan 3
# [N=111 Approx] state=9238, phase=0.5638, r=94, faktor=3 dan 1
# [N=111 Approx] state=1118, phase=0.0682, r=44, faktor=1 dan 3
# [N=111 Approx] state=7307, phase=0.4460, r=74, faktor=3 dan 1
# [N=111 Approx] state=14987, phase=0.9147, r=82, faktor=3 dan 1
# [N=111 Approx] state=13271, phase=0.8100, r=100, faktor=1 dan 3
# [N=111 Approx] state=1365, phase=0.0833, r=12, faktor=1 dan 3
# [N=111 Approx] state=3442, phase=0.2101, r=100, faktor=1 dan 3
# [N=111 Approx] state=5916, phase=0.3611, r=36, faktor=37 dan 3
# [N=111 Approx] state=13803, phase=0.8425, r=108, faktor=37 dan 3
# [N=111 Approx] state=16057, phase=0.9800, r=50, faktor=3 dan 1
# [N=111 Approx] state=13775, phase=0.8408, r=44, faktor=1 dan 3
# [N=111 Approx] state=7134, phase=0.4354, r=62, faktor=3 dan 1
# [N=111 Approx] state=5977, phase=0.3648, r=74, faktor=3 dan 1
# [N=111 Approx] state=6532, phase=0.3987, r=108, faktor=37 dan 3
# [N=111 Approx] state=3243, phase=0.1979, r=96, faktor=1 dan 3
# [N=111 Approx] state=1849, phase=0.1129, r=62, faktor=3 dan 1
# [N=111 Approx] state=6766, phase=0.4130, r=46, faktor=3 dan 1
# [N=111 Approx] state=10158, phase=0.6200, r=50, faktor=3 dan 1
# [N=111 Approx] state=3673, phase=0.2242, r=58, faktor=3 dan 1
# [N=111 Approx] state=15548, phase=0.9490, r=98, faktor=3 dan 1
# [N=111 Approx] state=11833, phase=0.7222, r=18, faktor=3 dan 1
# [N=111 Approx] state=2990, phase=0.1825, r=104, faktor=1 dan 3
# [N=111 Approx] state=6882, phase=0.4200, r=50, faktor=3 dan 1
# [N=111 Approx] state=455, phase=0.0278, r=36, faktor=37 dan 3
# [N=111 Approx] state=8156, phase=0.4978, r=2, faktor=3 dan 1
# [N=111 Approx] state=12093, phase=0.7381, r=42, faktor=3 dan 1
# [N=111 Approx] state=15164, phase=0.9255, r=94, faktor=3 dan 1
# [N=111 Approx] state=3186, phase=0.1945, r=36, faktor=37 dan 3
# [N=111 Approx] state=15993, phase=0.9761, r=42, faktor=3 dan 1
# [N=111 Approx] state=8028, phase=0.4900, r=100, faktor=1 dan 3
# [N=111 Approx] state=9557, phase=0.5833, r=12, faktor=1 dan 3
# [N=111 Approx] state=9849, phase=0.6011, r=108, faktor=37 dan 3
# [N=111 Approx] state=13198, phase=0.8055, r=36, faktor=37 dan 3
# [N=111 Approx] state=5071, phase=0.3095, r=42, faktor=3 dan 1
# [N=111 Approx] state=10890, phase=0.6647, r=110, faktor=3 dan 1
# [N=111 Approx] state=2803, phase=0.1711, r=76, faktor=1 dan 3
# [N=111 Approx] state=5932, phase=0.3621, r=58, faktor=3 dan 1
# [N=111 Approx] state=3769, phase=0.2300, r=100, faktor=1 dan 3
# [N=111 Approx] state=4096, phase=0.2500, r=4, faktor=1 dan 3
# [N=111 Approx] state=3385, phase=0.2066, r=92, faktor=1 dan 3
# [N=111 Approx] state=8903, phase=0.5434, r=46, faktor=3 dan 1
# [N=111 Approx] state=6507, phase=0.3972, r=68, faktor=1 dan 3
# [N=111 Approx] state=6585, phase=0.4019, r=102, faktor=3 dan 1
# [N=111 Approx] state=15019, phase=0.9167, r=12, faktor=1 dan 3
# [N=111 Approx] state=1878, phase=0.1146, r=96, faktor=1 dan 3
# [N=111 Approx] state=11897, phase=0.7261, r=84, faktor=1 dan 3
# [N=111 Approx] state=12971, phase=0.7917, r=24, faktor=1 dan 3
# [N=111 Approx] state=11506, phase=0.7023, r=84, faktor=1 dan 3
# [N=111 Approx] state=7538, phase=0.4601, r=50, faktor=3 dan 1
# [N=111 Approx] state=6449, phase=0.3936, r=94, faktor=3 dan 1
# [N=111 Approx] state=15050, phase=0.9186, r=86, faktor=3 dan 1
# [N=111 Approx] state=3116, phase=0.1902, r=100, faktor=1 dan 3
# [N=111 Approx] state=15403, phase=0.9401, r=50, faktor=3 dan 1
# [N=111 Approx] state=11115, phase=0.6784, r=28, faktor=1 dan 3
# [N=111 Approx] state=9294, phase=0.5673, r=104, faktor=1 dan 3
# [N=111 Approx] state=178, phase=0.0109, r=92, faktor=1 dan 3
# [N=111 Approx] state=2532, phase=0.1545, r=110, faktor=3 dan 1
# [N=111 Approx] state=8647, phase=0.5278, r=36, faktor=37 dan 3
# [N=111 Approx] state=11378, phase=0.6945, r=36, faktor=37 dan 3
# [N=111 Approx] state=10727, phase=0.6547, r=84, faktor=1 dan 3
# [N=111 Approx] state=1934, phase=0.1180, r=110, faktor=3 dan 1
# [N=111 Approx] state=3316, phase=0.2024, r=84, faktor=1 dan 3
# [N=111 Approx] state=13767, phase=0.8403, r=94, faktor=3 dan 1
# [N=111 Approx] state=14238, phase=0.8690, r=84, faktor=1 dan 3
# [N=111 Approx] state=1397, phase=0.0853, r=82, faktor=3 dan 1
# [N=111 Approx] state=463, phase=0.0283, r=106, faktor=3 dan 1
# [N=111 Approx] state=14108, phase=0.8611, r=36, faktor=37 dan 3
# [N=111 Approx] state=6827, phase=0.4167, r=12, faktor=1 dan 3
# [N=111 Approx] state=15278, phase=0.9325, r=74, faktor=3 dan 1
# [N=111 Approx] state=9559, phase=0.5834, r=12, faktor=1 dan 3
# [N=111 Approx] state=983, phase=0.0600, r=50, faktor=3 dan 1
# [N=111 Approx] state=911, phase=0.0556, r=18, faktor=3 dan 1
# [N=111 Approx] state=2218, phase=0.1354, r=96, faktor=1 dan 3
# [N=111 Approx] state=15531, phase=0.9479, r=96, faktor=1 dan 3
# [N=111 Approx] state=3242, phase=0.1979, r=96, faktor=1 dan 3
# [N=111 Approx] state=16174, phase=0.9872, r=78, faktor=3 dan 1
# [N=111 Approx] state=10980, phase=0.6702, r=94, faktor=3 dan 1
# [N=111 Approx] state=1508, phase=0.0920, r=76, faktor=1 dan 3
# [N=111 Approx] state=1302, phase=0.0795, r=88, faktor=1 dan 3
# [N=111 Approx] state=9167, phase=0.5595, r=84, faktor=1 dan 3
# [N=111 Approx] state=4551, phase=0.2778, r=18, faktor=3 dan 1
# [N=111 Approx] state=5079, phase=0.3100, r=100, faktor=1 dan 3
# [N=111 Approx] state=11961, phase=0.7300, r=100, faktor=1 dan 3
# [N=111 Approx] state=13593, phase=0.8297, r=88, faktor=1 dan 3
# [N=111 Approx] state=12779, phase=0.7800, r=50, faktor=3 dan 1
# [N=111 Approx] state=10468, phase=0.6389, r=36, faktor=37 dan 3
# [N=111 Approx] state=12147, phase=0.7414, r=58, faktor=3 dan 1
# [N=111 Approx] state=5948, phase=0.3630, r=102, faktor=3 dan 1
# [N=111 Approx] state=6956, phase=0.4246, r=106, faktor=3 dan 1
# [N=111 Approx] state=9685, phase=0.5911, r=22, faktor=3 dan 1
# [N=111 Approx] state=11869, phase=0.7244, r=98, faktor=3 dan 1
# [N=111 Approx] state=13653, phase=0.8333, r=6, faktor=3 dan 1
# [N=111 Approx] state=7339, phase=0.4479, r=96, faktor=1 dan 3
# [N=111 Approx] state=14109, phase=0.8611, r=36, faktor=37 dan 3
# [N=111 Approx] state=2730, phase=0.1666, r=6, faktor=3 dan 1
# [N=111 Approx] state=15474, phase=0.9445, r=18, faktor=3 dan 1
# [N=111 Approx] state=6374, phase=0.3890, r=18, faktor=3 dan 1
# [N=111 Approx] state=7537, phase=0.4600, r=50, faktor=3 dan 1
# [N=111 Approx] state=3556, phase=0.2170, r=106, faktor=3 dan 1
# [N=111 Approx] state=15610, phase=0.9528, r=106, faktor=3 dan 1
# [N=111 Approx] state=878, phase=0.0536, r=56, faktor=1 dan 3
# [N=111 Approx] state=11436, phase=0.6980, r=96, faktor=1 dan 3
# [N=111 Approx] state=2877, phase=0.1756, r=74, faktor=3 dan 1
# [N=111 Approx] state=13655, phase=0.8334, r=6, faktor=3 dan 1
# [N=111 Approx] state=8192, phase=0.5000, r=2, faktor=3 dan 1
# [N=111 Approx] state=6370, phase=0.3888, r=18, faktor=3 dan 1
# [N=111 Approx] state=16189, phase=0.9881, r=84, faktor=1 dan 3
# [N=111 Approx] state=747, phase=0.0456, r=22, faktor=3 dan 1
# [N=111 Approx] state=3322, phase=0.2028, r=74, faktor=3 dan 1
# [N=111 Approx] state=10012, phase=0.6111, r=18, faktor=3 dan 1
# [N=111 Approx] state=7314, phase=0.4464, r=56, faktor=1 dan 3
# [N=111 Approx] state=16056, phase=0.9800, r=50, faktor=3 dan 1
# [N=111 Approx] state=6954, phase=0.4244, r=106, faktor=3 dan 1
# [N=111 Approx] state=7851, phase=0.4792, r=48, faktor=1 dan 3
# [N=111 Approx] state=2276, phase=0.1389, r=36, faktor=37 dan 3
# [N=111 Approx] state=7371, phase=0.4499, r=20, faktor=1 dan 3
# [N=111 Approx] state=11186, phase=0.6827, r=104, faktor=1 dan 3
# [N=111 Approx] state=9137, phase=0.5577, r=52, faktor=1 dan 3
# [N=111 Approx] state=6826, phase=0.4166, r=12, faktor=1 dan 3
# [N=111 Approx] state=13047, phase=0.7963, r=54, faktor=3 dan 1
# [N=111 Approx] state=8877, phase=0.5418, r=24, faktor=1 dan 3
# [N=111 Approx] state=15163, phase=0.9255, r=94, faktor=3 dan 1
# [N=111 Approx] state=5534, phase=0.3378, r=74, faktor=3 dan 1
# [N=111 Approx] state=1566, phase=0.0956, r=94, faktor=3 dan 1
# [N=111 Approx] state=6955, phase=0.4245, r=106, faktor=3 dan 1
# [N=111 Approx] state=2787, phase=0.1701, r=100, faktor=1 dan 3
# [N=111 Approx] state=9155, phase=0.5588, r=34, faktor=3 dan 1
# [N=111 Approx] state=1305, phase=0.0797, r=88, faktor=1 dan 3
# [N=111 Approx] state=12719, phase=0.7763, r=76, faktor=1 dan 3
# [N=111 Approx] state=9118, phase=0.5565, r=106, faktor=3 dan 1
# [N=111 Approx] state=10013, phase=0.6111, r=18, faktor=3 dan 1
# [N=111 Approx] state=7737, phase=0.4722, r=36, faktor=37 dan 3
# [N=111 Approx] state=12288, phase=0.7500, r=4, faktor=1 dan 3
# [N=111 Approx] state=16043, phase=0.9792, r=48, faktor=1 dan 3
# [N=111 Approx] state=2845, phase=0.1736, r=98, faktor=3 dan 1
# [N=111 Approx] state=15701, phase=0.9583, r=24, faktor=1 dan 3
# [N=111 Approx] state=9561, phase=0.5836, r=12, faktor=1 dan 3
# [N=111 Approx] state=9679, phase=0.5908, r=22, faktor=3 dan 1
# [N=111 Approx] state=2723, phase=0.1662, r=6, faktor=3 dan 1
# [N=111 Approx] state=11837, phase=0.7225, r=18, faktor=3 dan 1
# [N=111 Approx] state=14254, phase=0.8700, r=100, faktor=1 dan 3
# [N=111 Approx] state=8601, phase=0.5250, r=40, faktor=1 dan 3
# [N=111 Approx] state=11435, phase=0.6979, r=96, faktor=1 dan 3
# [N=111 Approx] state=6375, phase=0.3891, r=18, faktor=3 dan 1
# [N=111 Approx] state=10981, phase=0.6702, r=94, faktor=3 dan 1
# [N=111 Approx] state=5821, phase=0.3553, r=76, faktor=1 dan 3
# [N=111 Approx] state=7062, phase=0.4310, r=58, faktor=3 dan 1
# [N=111 Approx] state=910, phase=0.0555, r=18, faktor=3 dan 1
# [N=111 Approx] state=14807, phase=0.9037, r=52, faktor=1 dan 3
# [N=111 Approx] state=11581, phase=0.7068, r=58, faktor=3 dan 1
# [N=111 Approx] state=1401, phase=0.0855, r=82, faktor=3 dan 1
# [N=111 Approx] state=4781, phase=0.2918, r=24, faktor=1 dan 3
# [N=111 Approx] state=6030, phase=0.3680, r=106, faktor=3 dan 1
# [N=111 Approx] state=2844, phase=0.1736, r=98, faktor=3 dan 1
# [N=111 Approx] state=1950, phase=0.1190, r=42, faktor=3 dan 1
# [N=111 Approx] state=15929, phase=0.9722, r=36, faktor=37 dan 3
# [N=111 Approx] state=10581, phase=0.6458, r=48, faktor=1 dan 3
# [N=111 Approx] state=2411, phase=0.1472, r=34, faktor=3 dan 1
#
# Correctness N=15  → Exact: 74.88%  Approx: 75.14%
# Correctness N=111 → Exact: 71.88%  Approx: 44.63%

# %%
states1 = np.arange(Q1)
states2 = np.arange(Q2)

plt.figure(figsize=(12,8))

# (a) N=15 Exact
plt.subplot(2,2,1)
plt.bar(states1, prob_exact1, label='Simulated', width=2)
peak_x1 = np.where(prob_theory1 > 0)[0]
plt.vlines(peak_x1, 0, prob_theory1[peak_x1], colors='red', linewidth=1.5, label='Theory')
plt.xlabel('States')
plt.ylabel('Frequency')
plt.title("(a) N=15 Exact QFT")
plt.legend()

# (b) N=111 Exact
plt.subplot(2,2,2)
plt.bar(states2, prob_exact2, label='Simulated', width=1)
peak_x2 = np.where(prob_theory2 > 0)[0]
plt.vlines(peak_x2, 0, prob_theory2[peak_x2], colors='red', linewidth=1.5, label='Theory')
plt.xlabel('States')
plt.ylabel('Frequency')
plt.title("(b) N=111 Exact QFT")
plt.legend()

# (c) N=15 Approx
plt.subplot(2,2,3)
plt.bar(states1, prob_approx1, label='Simulated', width=2)
plt.vlines(peak_x1, 0, prob_theory1[peak_x1], colors='red', linewidth=1.5, label='Theory')
plt.xlabel('States')
plt.ylabel('Frequency')
plt.title("(c) N=15 Approx QFT")
plt.legend()

# (d) N=111 Approx
plt.subplot(2,2,4)
plt.bar(states2, prob_approx2, label='Simulated', width=1)
plt.vlines(peak_x2, 0, prob_theory2[peak_x2], colors='red', linewidth=1.5, label='Theory')
plt.xlabel('States')
plt.ylabel('Frequency')
plt.title("(d) N=111 Approx QFT")
plt.legend()

plt.tight_layout()
plt.savefig('fig3_shor.png', dpi=150, bbox_inches='tight')
plt.show()
